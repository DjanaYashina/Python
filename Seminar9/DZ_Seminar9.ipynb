# %% [markdown]
# ***Задача 40***
# -  Работать с файлом california_housing_train.csv, который находится в папке sample_data.

# %%
import pandas as pd

# %%
df=pd.read_csv('sample_data/california_housing_train.csv')
df.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5847     -118.20     34.03                41.0       1292.0           334.0
# 9697     -119.57     36.44                30.0       1860.0           337.0
# 7372     -118.35     34.09                35.0       2705.0           785.0
# 15377    -122.29     37.54                43.0       2268.0           438.0
# 3502     -117.90     33.88                28.0       2696.0           346.0
# 2204     -117.38     33.19                26.0       4123.0          1145.0
# 1447     -117.19     33.53                 6.0        108.0            18.0
# 13875    -122.02     36.99                30.0       2156.0           487.0
# 13678    -121.99     37.33                35.0       1802.0           291.0
# 5374     -118.15     33.98                17.0       3361.0           925.0
#
#        population  households  median_income  median_house_value
# 5847       1150.0       322.0         1.9250            135200.0
# 9697       1123.0       347.0         3.4926             94200.0
# 7372       1526.0       793.0         3.0349            266700.0
# 15377      1151.0       449.0         4.9091            293200.0
# 3502        947.0       356.0         9.0055            375400.0
# 2204       1703.0       895.0         1.9891            500000.0
# 1447         43.0        17.0         3.4750            187500.0
# 13875      1023.0       458.0         2.7875            245000.0
# 13678       841.0       315.0         4.8365            313900.0
# 5374       3264.0       914.0         2.2813            145600.0

# %% [markdown]
# - Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
df[df['population'] < 500].median_house_value.mean().round
# Out:
# 206683.84

# %% [markdown]
# ***Задача 42***
# - Узнать какая максимальная households в зоне минимального значения population.

# %%
df[df['population'] == df['population'].min()].households.max()
# Out:
# 4.0
